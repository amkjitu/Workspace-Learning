# %% [markdown]
# Ekhon amra shikhbo Basic Neural Network

# %% [markdown]
# Biologyr je neurone seta AI te perceptron.
#
# 1. Percepntion,
#    \begin{equation*}
#    z = \left( \sum\_{i=1}^n w_i x_i \right)
#    \end{equation*}
#
# 2. Activation functions,
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# 3. Cost Functions
#
# ![image-5.png](attachment:image-5.png)
#
# Gradient Descent
#
# ![image-6.png](attachment:image-6.png)
#
# Back Propagation
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ANN er bivinno layer niye visualization
# playground.tensorflow.org
#
# kivabe markdown e equation likhte hoy
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Typesetting%20Equations.html

# %%
import openai as ai

print("Manual Neural Network")
# DragGan
# https://zeqiang-lai.github.io/blog/en/posts/drag_gan/
# Out:
# Manual Neural Network
# ERROR: unknown command "python"
