# %%
from IPython.display import Image

# %%
pwd
# Out:
# 'c:\\Users\\HP 840 G1\\Documents\\VS Code Projects\\Workspace Learning\\Thesis_CSIT\\Fire\\FireDetectionYOLOv8'

# %%
# !git clone https://github.com/MuhammadMoinFaisal/FireDetectionYOLOv8.git
# Out:
# ^C

# %%
# %cd c:/Users/HP 840 G1/Documents/VS Code Projects/Workspace Learning/Thesis_CSIT/Fire/FireDetectionYOLOv8
# Out:
# c:\Users\HP 840 G1\Documents\VS Code Projects\Workspace Learning\Thesis_CSIT\Fire\FireDetectionYOLOv8

# %%
#!pip install -e '.[dev]'
# !python setup.py install
# Out:
# ERROR: '.[dev]' is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).
# running install
# running bdist_egg
# running egg_info
# writing ultralytics.egg-info\PKG-INFO
# writing dependency_links to ultralytics.egg-info\dependency_links.txt
# writing entry points to ultralytics.egg-info\entry_points.txt
# writing requirements to ultralytics.egg-info\requires.txt
# writing top-level names to ultralytics.egg-info\top_level.txt
# reading manifest file 'ultralytics.egg-info\SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'ultralytics.egg-info\SOURCES.txt'
# installing library code to build\bdist.win-amd64\egg
# running install_lib
# running build_py
# creating build\bdist.win-amd64\egg
# ...

# %%
pwd
# Out:
# 'c:\\Users\\HP 840 G1\\Documents\\VS Code Projects\\Workspace Learning\\Thesis_CSIT\\Fire\\FireDetectionYOLOv8'

# %%
# %cd c:/Users/HP 840 G1/Documents/VS Code Projects/Workspace Learning/Thesis_CSIT/Fire/FireDetectionYOLOv8
# Out:
# c:\Users\HP 840 G1\Documents\VS Code Projects\Workspace Learning\Thesis_CSIT\Fire\FireDetectionYOLOv8

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KRl7MmkK5Na8s9ci4KzV")
project = rf.workspace("ai-training-course-rximv").project("fire-and-smoke-detection-vzqpf")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# quick-mail 1.0.4 requires chardet==3.0.4, but you have chardet 4.0.0 which is incompatible.
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/70.2 kB ? eta -:--:--
#      ----------------------                 41.0/70.2 kB 960.0 kB/s eta 0:00:01
#      -------------------------------------- 70.2/70.2 kB 952.5 kB/s eta 0:00:00
# ...
#                                               0.0/158.3 kB ? eta -:--:--
#      ----------------------------------     143.4/158.3 kB 4.3 MB/s eta 0:00:01
#      -------------------------------------- 158.3/158.3 kB 3.2 MB/s eta 0:00:00
# ...
#                                               0.0/178.7 kB ? eta -:--:--
# ...

# %%
HOME = 'c:/Users/HP 840 G1/Documents/VS Code Projects/Workspace Learning/Thesis_CSIT/Fire/FireDetectionYOLOv8/ultralytics/yolo/v8/detect/'

# %%
# %cd {HOME}
# Out:
# c:\Users\HP 840 G1\Documents\VS Code Projects\Workspace Learning\Thesis_CSIT\Fire\FireDetectionYOLOv8\ultralytics\yolo\v8\detect

# %%
# %cd {dataset.location}
# Out:
# [WinError 2] The system cannot find the file specified: '{dataset.location}'
# c:\Users\HP 840 G1\Documents\VS Code Projects\Workspace Learning\Thesis_CSIT\Fire\FireDetectionYOLOv8\ultralytics\yolo\v8\detect

# %%
# %cd {HOME}
# Out:
# c:\Users\HP 840 G1\Documents\VS Code Projects\Workspace Learning\Thesis_CSIT\Fire\FireDetectionYOLOv8\ultralytics\yolo\v8\detect

# %%
# !python train.py model=yolov8s.pt data={dataset.location}/data.yaml epochs=128 imgsz=640
# Out:
# Traceback (most recent call last):
#   File "c:\Users\HP 840 G1\Documents\VS Code Projects\Workspace Learning\Thesis_CSIT\Fire\FireDetectionYOLOv8\ultralytics\yolo\v8\detect\train.py", line 10, in <module>
#     from ultralytics.yolo import v8
# ModuleNotFoundError: No module named 'ultralytics.yolo'
